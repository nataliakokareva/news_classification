# %% [markdown]
# Классификация - распространенная задача в сфере обработки текстов. В данном соревновании мы будем классифицировать настоящие данные с сайта Lenta.ru по пяти тематикам:
#
# Экономика
#
# Спорт
#
# Культура
#
# Наука и техника
#
# Бизнес
#
# В данных присутствуют два поля: заголовок (title) и сам текст статьи (text). Вы можете использовать одно из полей или оба для определения класса. Метка класса лежит в поле topic_label.

# %%
import pandas as pd
import numpy as np

import urllib.request # библиотека для скачивания данных
import gensim # библиотека для загрузки и использвоания моделй w2v
from gensim.models import word2vec # непосредственно методы w2v

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV

import warnings
warnings.filterwarnings("ignore")

import nltk.data # библиотека Natural Language Toolkit
import re   # библиотека для регулярных выражений
from nltk.corpus import stopwords # стоп-слова из NLTK
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer  # токенизаторы из NLTK
nltk.download('punkt') # для правильной работы токенизатора

from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nataliakokareva/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data = pd.read_csv('lenta-ru-train.csv')
data.shape
# Out:
# (206637, 4)

# %%
data_small = data[:100000]
texts = data_small['text'].values
titles = data_small['title'].values
labels = data_small['topic_label'].values

# %%
len(texts)
# Out:
# 100000

# %% [markdown]
# ### Токенизация и лемматизация
# Каждый раз можно это не запускать. Леммы уже сохранены в файле 'lenta-ru-train-small-lem-tag-text.csv'
# См. пункт "загрузка предварительно сохраненных данных

# %%
from pymystem3 import Mystem

# %%
#text_tokens = []
tmp_lemmas = []
m = Mystem()
for text in texts:
    lem = []
    clean_text = re.sub('[^A-Za-z0-9А-Яа-я]+', ' ', text)
    tkn = clean_text.split()
    for t in tkn:
        lem.append(m.lemmatize(t))
    tmp_lemmas.append(lem)
    #text_tokens.append(tkn)

# %%
text_lemmas = []
for sent in tmp_lemmas:
    tmp = []
    for word in sent:
        tmp.append(word[0].rstrip('\n'))
    text_lemmas.append(' '.join(tmp))

# %%
m = Mystem()
lem_tag = []
for text in text_lemmas:
    p = m.analyze(text)
    tmp = []
    for word in p:
        if 'analysis' in word:
            if word['analysis'] != []:
                tup = (word['analysis'][0]['lex'], word['analysis'][0]['gr'].split('=')[0].split(',')[0])
                tmp.append('_'.join(tup))
    lem_tag.append(' '.join(tmp))
lem_tag
# Out:
# ['глава_S росстат_S владимир_S соколин_S заявлять_V что_CONJ в_PR январь_S год_S темп_S рост_S цена_S в_PR россия_S составлять_V процент_S то_CONJ быть_V столько_NUM же_PART сколько_CONJ они_SPRO составлять_V в_PR январь_S прошлое_S год_S писать_V ведомость_S тогда_ADVPRO как_ADVPRO и_CONJ в_PR год_S правительство_S планировать_V удерживать_V инфляция_S в_PR предел_S процент_S однако_CONJ в_PR год_S прогноз_S рост_S цена_S приходиться_V дважды_ADV пересматривать_V сначала_ADV до_PR а_CONJ затем_ADV до_PR процент_S кроме_PR то_SPRO чиновник_S отчитываться_V за_PR год_S в_PR качество_S основной_A причина_S высокий_A темп_S рост_S цена_S в_PR год_S указывать_V именно_PART на_PR январский_A инфляция_S в_PR частность_S на_PR повышение_S в_PR январь_S тариф_S на_PR услуга_S жкх_S увеличение_S бюджетный_A расход_S в_PR связь_S с_PR мон
_S общий_A ситуация_S в_PR украинский_A экономика_S сейчас_ADV самый_APRO сложный_A за_PR последний_A год_S плохо_ADV быть_V только_PART во_PR время_S великий_A отечественный_A война_S заявлять_V глава_S национальный_A банк_S страна_S среди_PR главный_A причина_S падение_S украинский_A экономика_S гонтарев_S называть_V война_S в_PR донбасс_S выход_S из_PR состав_S украина_S крым_S а_CONJ также_ADV панический_A настроение_S население_S и_CONJ представитель_S бизнес_S ранее_ADV правительство_S украина_S прогнозировать_V снижение_S ввп_S страна_S в_PR год_S на_PR процент_S в_PR ноябрь_S премьер_S министр_S арсений_S яценюк_S не_PART исключать_V падение_S это_PART показатель_S на_PR процент_S',
#  'студия_S отказываться_V добавлять_V в_PR командный_A матч_S как_CONJ сообщать_V в_PR официальный_A блог_S проект_S глава_S разработчик_S игра_S джей_S уилсон_S компания_S забраковывать_V система_S над_PR который_APRO они_SPRO трудиться_V в_PR последний_A месяц_S он_SPRO объяснять_V что_CONJ коллективный_A бой_S между_PR игрок_S в_PR то_SPRO вид_S в_PR какой_APRO они_SPRO существовать_V сейчас_ADV оказываться_V слишком_ADV скучный_A и_CONJ бессмысленный_A так_ADVPRO как_CONJ в_PR бой_S не_PART быть_V никакой_APRO цель_S а_CONJ игрок_S не_PART доставаться_V никакой_APRO награда_S уилсон_S добавлять_V что_CONJ разработчик_S не_PART удаваться_V добиваться_V баланс_S между_PR класс_S в_PR командный_A он_SPRO отмечать_V что_CONJ попытка_S достигать_V нужный_A результат_S в_PR мочь_V бы_PART повреждать_V режим_S в_S поэтому_ADVPRO студия_S отказываться_V от_PR этот_APRO идея_S уилсон_S заверять_V что_CONJ одиночный_A дуэль_S в_PR игра_S то_PART не_PART менее_ADV появляться_V обновление_S который_APRO добавлять_V они_SPRO в_PR должно_ADV выходить_V в_PR год_S точный_A дата_S он_SPRO релиз_S не_PART называться_V глава_S разработчик_S также_ADV объяснять_V что_CONJ студия_S не_PART собираться_V полностью_ADV отказываться_V от_PR система_S командный_A поэтому_ADVPRO команда_S приступать_V к_PR разработка_S она_SPRO новый_A версия_S он_SPRO также_ADV пообещать_V что_CONJ там_ADVPRO появляться_V награда_S для_PR игрок_S а_CONJ также_ADV быть_V иной_APRO занятие_S помимо_PR взаимный_A смертоубийство_S однако_CONJ о_PR что_SPRO именно_PART идти_V речь_S уилсон_S говорить_V не_PART становиться_V он_SPRO также_ADV не_PART уточнять_V когда_CONJ приблизительно_ADV мочь_V быть_V готовый_A новый_A система_S выходить_V в_PR май_S год_S первоначально_ADV планироваться_V что_CONJ в_PR игра_S сразу_ADV быть_V режим_S однако_CONJ непосредственно_ADV перед_PR релиз_S объявлять_V что_CONJ он_SPRO требовать_V доработка_S поэтому_ADVPRO выходить_V поздно_ADV разработчик_S продолжать_V создание_S новый_A режим_S и_CONJ даже_PART успевать_V показывать_V он_SPRO на_PR несколько_NUM игровой_A мероприятие_S однако_CONJ никакой_APRO точный_A срок_S он_SPRO релиз_S не_PART называться_V',
# ...
#  'масштабный_A исследование_S проводить_V британский_A палеонтолог_S показывать_V что_CONJ почти_ADV процент_S весь_APRO вид_S динозавр_S быть_V называть_V неправильно_ADV об_PR это_SPRO сообщаться_V в_PR пресс_S релиз_S на_PR официальный_A сайт_S бристольский_A университет_S сотрудник_S который_APRO принимать_V участие_S в_PR исследование_S работа_S ученый_S опубликовывать_V в_PR журнал_S для_PR свой_APRO исследование_S палеонтолог_S изучать_V оригинальный_A описание_S весь_APRO вид_S динозавр_S открывать_V с_PR год_S по_PR год_S в_PR результат_S быть_V устанавливать_V что_CONJ процент_S имя_S являться_V дубликат_S то_CONJ быть_V принадлежать_V динозавр_S у_PR который_APRO уже_ADV быть_V другой_APRO имя_S еще_ADV в_PR процент_S случай_S имя_S новый_A вид_S даваться_V на_PR основание_S находка_S неудовлетворительный_A качество_S по_PR слово_S ученый_S это_PART связанный_A с_PR то_SPRO что_CONJ в_PR прошлое_S палеонтолог_S испытывать_V серьезный_A давление_S со_PR сторона_S научный_A институт_S и_CONJ журнал_S который_APRO и_CONJ заставлять_V они_SPRO объявлять_V об_PR открытие_S новый_A вид_S не_PART доводить_V до_PR конец_S необходимый_A формальность_S однако_CONJ исследователь_S утверждать_V что_CONJ начинать_V с_PR шестидесятый_ANUM год_S прошлое_S век_S качество_S открытие_S заметно_ADV улучшаться_V сейчас_ADV новый_A вид_S открывать_V в_PR средний_A два_NUM раз_S в_PR месяц_S чтобы_CONJ продемонстрировать_V положительный_A изменение_S ученый_S составлять_V список_S самый_APRO плодовитый_A на_PR имя_S палеонтолог_S он_SPRO возглавлять_V отнять_V марш_S который_APRO называть_V американский_A король_S динозавр_S по_PR год_S король_S заявлять_V об_PR открытие_S новый_A вид_S гигантский_A ящер_S раз_CONJ из_PR они_SPRO только_PART проходить_V проверка_S время_S по_PR слово_S ученый_S количество_S правильный_A имя_S динозавр_S давать_V палеонтолог_S из_PR первый_ANUM пятерка_S список_S варьироваться_V от_PR до_PR процент_S самый_APRO активный_A современный_A специалист_S по_PR динозавр_S признавать_V китайский_A палеонтолог_S син_S с_S по_PR год_S син_S открывать_V вид_S динозавр_S в_PR средний_A три_NUM открытие_S в_PR год_S и_CONJ все_SPRO открытие_S быть_V признавать_V научный_A сообщество_S',
#  'единственный_A миниатюра_S изображать_V леди_S джейн_S грей_S английский_A королев_S править_V всего_PART девять_NUM день_S в_PR год_S находить_V в_PR американский_A коллекция_S известный_A британский_A специалист_S по_PR тюдоровский_A англия_S дэвид_S старка_S узнавать_V несчастный_A монархиня_S она_SPRO обезглавливать_V по_PR лист_S левка_S геральдический_A символ_S герцог_S дадли_S муж_S леди_S джейн_S о_PR находка_S сообщать_V лондонский_A газета_S на_PR миниатюра_S написать_V предположительно_ADV портретистка_S фламандский_A происхождение_S лавиния_S теерлинк_S изображать_V сидеть_V молодой_A женщина_S она_SPRO возраст_S указывать_V на_PR портрет_S год_S по_PR мнение_
ионат_S нет_PART но_CONJ затем_ADV наш_APRO партнер_S весь_APRO таки_PART поддаваться_V шантаж_S что_CONJ создавать_V опасный_A прецедент_S заявлять_V зубок_S он_SPRO также_ADV отмечать_V что_CONJ перенос_S мировой_A первенство_S факт_S очередной_A вмешательство_S политик_S в_PR спорт_S и_CONJ способ_S наказывать_V россия_S во_PR вторник_S декабрь_S объявлять_V о_PR перенос_S чемпионат_S мир_S который_APRO должный_A быть_V состояться_V в_PR сочи_S с_S по_PR февраль_S перед_PR это_SPRO о_PR бойкот_S соревнование_S заявлять_V латвийский_A и_CONJ южнокорейский_A скелетонист_S также_ADV об_PR это_SPRO шаг_S задумываться_V национальный_A команда_S сша_S',
#  'госдума_S к_PR конец_S осенний_A сессия_S до_PR декабрь_S год_S смочь_V принимать_V законодательство_S регулировать_V оборот_S криптовалюта_S в_PR россия_S об_PR это_SPRO в_PR интервью_S телеканал_S россия_S заявлять_V глава_S комитет_S по_PR финрынок_S председатель_S банковский_A ассоциация_S россия_S анатолий_S аксаков_S передавать_V риа_S новость_S если_CONJ мы_SPRO на_PR предстоять_V неделя_S договариваться_V об_PR основной_A подход_S то_CONJ думать_V уже_ADV осень_S к_PR конец_S осенний_A сессия_S мы_SPRO смочь_V принимать_V этот_APRO закон_S для_PR то_SPRO чтобы_CONJ обеспечивать_V правовой_A пространство_S для_PR развитие_S это_PART рынок_S приводить_V агентство_S он_SPRO слово_S аксаков_S также_ADV указывать_V на_PR нерешенный_A вопрос_S в_PR сфера_S регулирование_S криптовалюта_S по_PR он_SPRO слово_S сперва_ADV надо_ADV определять_V регулятор_S они_SPRO должный_A быть_V центробанк_S считать_V парламентарий_S также_ADV необходимо_ADV придавать_V цифровой_A деньги_S статус_S финансовый_A инструмент_S затем_ADV важно_ADV указывать_V кто_SPRO именно_PART смочь_V проводить_V с_PR они_SPRO операция_S россия_S становиться_V один_APRO из_PR первый_ANUM кто_SPRO быть_V законодательно_ADV регулировать_V рынок_S криптовалюта_S при_PR это_SPRO уже_ADV быть_V в_PR некоторый_APRO страна_S регулирование_S где_ADVPRO то_PART это_SPRO очень_ADV свободный_A в_PR африка_S вообще_ADV признавать_V что_CONJ это_PART свободный_A валюта_S важно_ADV учитывать_V международный_A опыт_S еще_ADV раз_S подчеркивать_V очень_ADV важно_ADV чтобы_CONJ этот_APRO рынок_S развиваться_V сказать_V он_SPRO август_S замглавы_S минфин_S россия_S алексей_S моисеев_S заявлять_V что_CONJ цифровой_A валюта_S необходимо_ADV регулировать_V как_CONJ финансовый_A актив_S при_PR это_SPRO частный_A лицо_S мочь_V запрещать_V покупать_V криптовалюта_S предполагаться_V что_CONJ операция_S с_PR они_SPRO смочь_V проводить_V только_PART квалифицированный_A инвестор_S через_PR московский_A биржа_S',
#  ...]

# %%
data_small['lem_tag'] = lem_tag
data_small.head()
# Out:
#                                                title  \
# 0  Инфляция в январе 2006 года составит 2,6 процента
# 1      Никита Михалков учредил День российского кино
# 2    Марко Матерацци вернется в строй к матчу с ЦСКА
# 3            Определены лауреаты премии "Книга года"
# 4  Гол Роналду со штрафного спас португальцев от ...
#
#                                                 text      topic  topic_label  \
# 0  Глава Росстата Владимир Соколин заявил, что в ...  Экономика            0
# 1  У российских кинематографистов  появится новый...   Культура            3
# 2  Медицинский штаб миланского "Интера" обнародов...      Спорт            1
# 3  Премии "Книга года" в 13 номинациях вручены на...   Культура            3
# 4  Сборная Португалии сыграла вничью с командой И...      Спорт            1
#
#                                              lem_tag
# 0  глава_S росстат_S владимир_S соколин_S заявлят...
# 1  у_PR российский_A кинематографист_S появляться...
# 2  медицинский_A штаб_S миланский_A интер_S обнар...
# 3  премия_S книга_S год_S в_PR номинация_S вручат...
# 4  сборная_S португалия_S сыграть_V вничью_ADV с_...

# %%
data_small.to_csv('lenta-ru-train-small-lem-tag-text.csv')

# %% [markdown]
# #### Загрузка предварительно сохраненных данных

# %%
data_new = pd.read_csv('lenta-ru-train-small-lem-tag-text.csv')
data_new.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Инфляция в январе 2006 года составит 2,6 процента
# 1           1      Никита Михалков учредил День российского кино
# 2           2    Марко Матерацци вернется в строй к матчу с ЦСКА
# 3           3            Определены лауреаты премии "Книга года"
# 4           4  Гол Роналду со штрафного спас португальцев от ...
#
#                                                 text      topic  topic_label  \
# 0  Глава Росстата Владимир Соколин заявил, что в ...  Экономика            0
# 1  У российских кинематографистов  появится новый...   Культура            3
# 2  Медицинский штаб миланского "Интера" обнародов...      Спорт            1
# 3  Премии "Книга года" в 13 номинациях вручены на...   Культура            3
# 4  Сборная Португалии сыграла вничью с командой И...      Спорт            1
#
#                                              lem_tag
# 0  глава_S росстат_S владимир_S соколин_S заявлят...
# 1  у_PR российский_A кинематографист_S появляться...
# 2  медицинский_A штаб_S миланский_A интер_S обнар...
# 3  премия_S книга_S год_S в_PR номинация_S вручат...
# 4  сборная_S португалия_S сыграть_V вничью_ADV с_...

# %%
data_new = data_new.replace(np.nan, '', regex=True)

# %%
lst = data_new['lem_tag'].values
lem_tag_read = []
for i in range(len(lst)):
    lem_tag_read.append(lst[i])

# %%
model_path = "ruscorpora_mean_hs.model.bin"
model_ru = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
len(model_ru['глава_S'])
# Out:
# 300

# %% [markdown]
# #### Средние эмбеддинги по всем словам отзыва

# %%
lem_tag_lst = []
for i in range(len(lem_tag_read)):
    lem_tag_lst.append(lem_tag_read[i].split())

# %%
mean_vec = []
for i in range(len(lem_tag_lst)):
    vec = np.zeros(300)
    for word in lem_tag_lst[i]:
            try:
                vec += model_ru[word]
            except:
                vec = vec
    mean_vec.append(vec / len(lem_tag_lst[i]))

# %%
len(mean_vec)
# Out:
# 100000

# %%
X = []
y = []
for i in range(len(mean_vec)):
    if np.isnan(mean_vec[i]).any() == True:
        continue
    X.append(mean_vec[i])
    y.append(labels[i])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

# %%
for clf in [LogisticRegression(), LinearSVC(), SGDClassifier()]:
    print(clf)
    print(cross_val_score(clf, X, y).mean())
    print("\n")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# 0.9254007391670612
#
#
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)
# 0.9386294880717415
#
#
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# 0.9219585091178706

# %% [markdown]
# #### Подбор параметров:

# %%
#LogisticRegression

grid_lr = {
    'C': np.logspace(-3,3,7),
    'penalty': ['l1', 'l2']
}

сlf_lr = LogisticRegression()
clf_lr_cv=GridSearchCV(сlf_lr,grid_lr,cv=10)
clf_lr_cv.fit(X,y)

print("LogisticRegression:")
print(f"Лучшее качество - {clf_lr_cv.best_score_}")
print(f"Параметры - {clf_lr_cv.best_params_}")
# Out:
# LogisticRegression:
# Лучшее качество - 0.9431524806372206
# Параметры - {'C': 1000.0, 'penalty': 'l1'}

# %%
#LinearSVC

grid_lsvc = {
    'loss': ['hinge', 'squared_hinge'], 
    'C': np.logspace(-3,3,7)
}

clf_lsvc = LinearSVC()
clf_lsvc_cv=GridSearchCV(clf_lsvc,grid_lsvc,cv=10)
clf_lsvc_cv.fit(X,y)

print("LinearSVC:")
print(f"Лучшее качество - {clf_lsvc_cv.best_score_}")
print(f"Параметры - {clf_lsvc_cv.best_params_}")
# Out:
# LinearSVC:
# Лучшее качество - 0.9428022494846598
# Параметры - {'C': 100.0, 'loss': 'squared_hinge'}

# %%
#SGDClassifier

grid_sgd = {
    'loss': ['log', 'hinge', 'modified_huber'], 
    'penalty':  ['l1', 'l2', 'elasticnet']
}

clf_sgd = SGDClassifier()
clf_sgd_cv=GridSearchCV(clf_sgd,grid_sgd,cv=10)
clf_sgd_cv.fit(X,y)

print("SGDClassifier:")
print(f"Лучшее качество - {clf_sgd_cv.best_score_}")
print(f"Параметры - {clf_sgd_cv.best_params_}")
# Out:
# SGDClassifier:
# Лучшее качество - 0.9335361338483399
# Параметры - {'loss': 'modified_huber', 'penalty': 'l1'}

# %% [markdown]
# #### Предобработка тестовых данных

# %%
data_test = pd.read_csv('lenta-ru-test.csv')
# Out:
# Index(['title', 'text', 'topic', 'topic_label'], dtype='object')

# %%
texts_test = data_test['text'].values
titles_test = data_test['title'].values

# %%
tmp_lemmas_test = []
m = Mystem()
for text in texts_test:
    lem = []
    clean_text = re.sub('[^A-Za-z0-9А-Яа-я]+', ' ', text)
    tkn = clean_text.split()
    for t in tkn:
        lem.append(m.lemmatize(t))
    tmp_lemmas_test.append(lem)

# %%
text_lemmas_test = []
for sent in tmp_lemmas_test:
    tmp = []
    for word in sent:
        tmp.append(word[0].rstrip('\n'))
    text_lemmas_test.append(' '.join(tmp))

# %%
m = Mystem()
lem_tag_test = []
for text in text_lemmas_test:
    p = m.analyze(text)
    tmp = []
    for word in p:
        if 'analysis' in word:
            if word['analysis'] != []:
                tup = (word['analysis'][0]['lex'], word['analysis'][0]['gr'].split('=')[0].split(',')[0])
                tmp.append('_'.join(tup))
    lem_tag_test.append(' '.join(tmp))
lem_tag_test[:3]
# Out:
# ['в_PR южноафриканский_A кейптаун_S победа_S сборная_S россия_S завершаться_V чемпионат_S мир_S среди_PR бездомный_S в_PR финальный_A матч_S российский_A футболист_S впервые_ADV в_PR свой_APRO история_S становиться_V чемпион_S мир_S обыгрывать_V команда_S казахстан_S со_PR счет_S передавать_V в_PR первенство_S принимать_V участие_S почти_ADV человек_S который_APRO представлять_V страна_S мир_S весь_APRO матч_S каждый_APRO из_PR который_APRO продолжаться_V минута_S проходить_V на_PR асфальтовый_A поле_S причем_CONJ в_PR один_APRO команда_S мочь_V играть_V как_CONJ мужчина_S так_ADVPRO и_CONJ женщина_S сборная_S россия_S проводить_V на_PR турнир_S матч_S во_PR весь_APRO из_PR который_APRO добиваться_V победа_S на_PR предыдущий_A чемпионат_S мир_S достижение_S российский_A команда_S быть_V скромный_A в_PR м_S год_S е_S место_S в_PR м_S год_S е_S место_S в_PR м_S год_S е_S место_S',
#  'анна_S курникова_S проигрывать_V испанка_S кончать_V мартинес_S уже_ADV в_PR первый_ANUM круг_S выбывать_V из_PR борьба_S за_PR победа_S в_PR турнир_S сообщать_V российский_A теннисистка_S уступать_V стартовый_A матч_S в_PR четыре_NUM подряд_ADV турнир_S в_PR поединок_S с_PR мартинес_S совершать_V семь_NUM двойной_A и_CONJ невынужденный_A ошибка_S сказать_V то_PART что_CONJ я_SPRO расстраивать_V значит_ADV не_PART сказать_V ничто_SPRO прокомментировать_V свой_APRO игра_S летний_A курников_S который_APRO в_PR май_S прошлое_S год_S в_PR рейтинг_S занимать_V восьмой_ANUM строчка_S а_CONJ заканчивать_V сезон_S й_S мартинес_S который_APRO в_PR день_S матч_S исполняться_V год_S оставаться_V довольный_A результат_S и_CONJ сказать_V что_CONJ курников_S иногда_ADV просто_PART не_PART проявлять_V достаточный_A терпение_S на_PR корт_S что_CONJ долго_ADV ты_SPRO проводить_V вне_PR игра_S то_CONJ трудно_ADV обретать_V былой_A форма_S у_PR я_SPRO тоже_PART быть_V этап_S когда_CONJ я_SPRO пропускать_V восемь_NUM месяц_S и_CONJ я_SPRO работать_V по_PR час_S в_PR сутки_S чтобы_CONJ снова_ADV выходить_V на_PR достойный_A уровень_S добавлять_V испанка_S еще_ADV один_ANUM представительница_S россия_S елена_S бовина_S также_ADV неудачно_ADV выступать_V на_PR турнир_S в_PR будапешт_S проигрывать_V в_PR два_NUM партия_S любомир_S бачев_S в_PR соревнование_S мужчина_S на_PR в_PR монт_S карло_S хороший_A российский_A теннисист_S марат_S сафин_S обыгрывать_V испанец_S томми_S робредо_S и_CONJ выходить_V во_PR второй_ANUM круг_S',
#  'новый_A главный_A тренер_S московский_A футбольный_A клуб_S спартак_S назначать_V бывший_A вратарь_S команда_S станислав_S черчесов_S в_PR последний_A время_S занимать_V должность_S спортивный_A директор_S черчесов_S приходить_V на_PR место_S владимир_S федотов_S который_APRO быть_V отправлять_V в_PR отставка_S во_PR вторник_S июнь_S после_PR встреча_S с_PR владелец_S клуб_S леонид_S федун_S сообщать_V спорт_S экспресс_S подробность_S назначение_S черчесов_S пока_CONJ неизвестный_A что_CONJ касаться_V федотов_S то_CONJ он_SPRO по_PR инфморация_S издание_S спорт_S сегодня_ADV занимать_V должность_S спортивный_A директор_S в_PR один_APRO из_PR московский_A клуб_S отмечать_V что_CONJ до_PR назначение_S на_PR пост_S главный_A тренер_S спартак_S апрель_S год_S федотов_S быть_V в_PR это_SPRO клуб_S именно_PART спортивный_A директор_S что_CONJ касаться_V черчесов_S то_CONJ он_SPRO до_PR возвращение_S в_PR спартак_S работать_V главный_A тренер_S австрийский_A тироль_S в_PR который_APRO завершать_V карьера_S футболист_S в_PR май_S год_S он_SPRO занимать_V пост_S спортивный_A директор_S спартак_S подписывать_V контракт_S на_PR полтора_NUM год_S после_PR тур_S спартак_S с_PR ю_S очки_S занимать_V четвертый_ANUM место_S в_PR чемпионат_S россия_S отставать_V от_PR идти_V на_PR первый_ANUM место_S цска_S и_CONJ зенит_S на_PR один_ANUM очко_S очередной_A матч_S первенство_S страна_S команда_S проводить_V уже_ADV в_PR пятница_S июнь_S когда_CONJ принимать_V подмосковный_A сатурн_S']

# %%
lem_tag_lst_test = []
for i in range(len(lem_tag_test)):
    lem_tag_lst_test.append(lem_tag_test[i].split())

# %%
mean_vec_test = []
for i in range(len(lem_tag_lst_test)):
    vec = np.zeros(300)
    for word in lem_tag_lst_test[i]:
            try:
                vec += model_ru[word]
            except:
                vec = vec
    mean_vec_test.append(vec / len(lem_tag_lst_test[i]))

# %%
X_test = []
for i in range(len(mean_vec_test)):
    if np.isnan(mean_vec_test[i]).any() == True:
        continue
    X_test.append(mean_vec_test[i])

# %% [markdown]
# #### Предсказания

# %%
# LogisticRegression. Параметры - {'C': 1000.0, 'penalty': 'l1'}

clf_lr = LogisticRegression(C = 1000, penalty = 'l1')
clf_lr.fit(X, y)
# Out:
# LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l1',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_lr = clf.predict(X_test)
y_pred_lr
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
# LinearSVC Параметры - {'C': 100.0, 'loss': 'squared_hinge'}
clf_lsvc = LinearSVC(C = 100, loss = 'squared_hinge')
clf_lsvc.fit(X, y)
y_pred_lsvc = clf_lsvc.predict(X_test)

# %%
y_pred_lsvc
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
# SGDClassifier Параметры - {'loss': 'modified_huber', 'penalty': 'l1'}
clf_sgd = SGDClassifier(loss = 'modified_huber', penalty = 'l1')
clf_sgd.fit(X, y)
y_pred_sgd = clf_sgd.predict(X_test)
y_pred_sgd
# Out:
# array([1, 1, 1, ..., 2, 1, 1])
